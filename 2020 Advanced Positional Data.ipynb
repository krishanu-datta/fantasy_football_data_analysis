# %%
## import relevant packages
import pandas as pd
import urllib.request as urllib
import requests
from bs4 import BeautifulSoup
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
teams = {
    1 : "Number Juan",
    2 : "Belichick Yourself",
    3 : "Scott",
    4 : "Hernandez Hit Men",
    5 : "Ayush",
    6 : "Krishanu",
    7 : "Matthew",
    8 : "Ankith",
    9 : "Bok Choy Babes",
    10 : "Davis",
    11 : "Ishaan",
    12 : "Nandha"
}

# %%
site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
site2 = '&week='
teamNumber = 4

weekNumber = 4
site = site1 + str(teamNumber) + site2 + str(weekNumber)
html = urllib.urlopen(site)
soup = BeautifulSoup(html.read())

# %%
## url setup
for a in range(1,13):
    df = pd.DataFrame()
    QB1name = []
    QB1position = []
    QB1team = []
    QB1win = []
    QB1points = []
    RB2name = []
    RB2position = []
    RB2team = []
    RB2win = []
    RB2points = []
    RB3name = []
    RB3position = []
    RB3team = []
    RB3win = []
    RB3points = []
    WR4name = []
    WR4position = []
    WR4team = []
    WR4win = []
    WR4points = []
    WR5name = []
    WR5position = []
    WR5team = []
    WR5win = []
    WR5points = []
    TE6name = []
    TE6position = []
    TE6team = []
    TE6win = []
    TE6points = []
    W_R7name = []
    W_R7position = []
    W_R7team = []
    W_R7win = []
    W_R7points = []
    K8name = []
    K8position = []
    K8team = []
    K8win = []
    K8points = []
    DEF9name = []
    DEF9position = []
    DEF9team = []
    DEF9win = []
    DEF9points = []
    team_score = []
    opponent_score = []
    margin = []
    wins = []
    
    site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
    site2 = '&week='
    teamNumber = a

    for j in range(0,13):
        weekNumber = j+1
        site = site1 + str(teamNumber) + site2 + str(weekNumber)
        html = urllib.urlopen(site)
        soup = BeautifulSoup(html.read())
        
        team_totals = soup.find_all("div",{"class": "teamTotal"})
        team_score.append(float(team_totals[0].get_text()))
        opponent_score.append(float(team_totals[1].get_text()))
        margin.append(float(team_totals[0].get_text()) - float(team_totals[1].get_text()))
        wins.append(bool(float(team_totals[0].get_text()) > float(team_totals[1].get_text())))
        
        player_stats = soup.find("div",{"class": "tableWrap"})
        tr_tags = player_stats.find_all("tr")
        for i in range(2, len(tr_tags)):
            team_position = tr_tags[i].find("td",{"class": "teamPosition"}).get_text() + str(i-1)
            info = tr_tags[i].find("td",{"class": "playerNameAndInfo"})
            if info.find("a", {"class": "playerCard"}) is not None:
                name = info.find("a", {"class": "playerCard"}).get_text()
            else:
                name = "N/A"
            if info.find("em") is not None:
                position = info.find("em").get_text().split()[0]
                if len(info.find("em").get_text().split()) > 1:
                    team = info.find("em").get_text().split()[2]
                else:
                    team = "N/A"
            else:
                position = "N/A"
                team = "N/A"
            if tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text() is not None:
                if len(tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()) > 0:
                    win = tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()[0]
                else:
                    win = "N/A"
            else:
                win = "N/A"
            if tr_tags[i].find("span",{"class": "playerTotal"}) is not None:
                points = float(tr_tags[i].find("span",{"class": "playerTotal"}).get_text())
            else:
                points = 0

            if team_position == "QB1":
                QB1name.append(name)
                QB1position.append(position)
                QB1team.append(team)
                QB1win.append(win)
                QB1points.append(points)
            if team_position == "RB2":
                RB2name.append(name)
                RB2position.append(position)
                RB2team.append(team)
                RB2win.append(win)
                RB2points.append(points)
            if team_position == "RB3":
                RB3name.append(name)
                RB3position.append(position)
                RB3team.append(team)
                RB3win.append(win)
                RB3points.append(points)
            if team_position == "WR4":
                WR4name.append(name)
                WR4position.append(position)
                WR4team.append(team)
                WR4win.append(win)
                WR4points.append(points)
            if team_position == "WR5":
                WR5name.append(name)
                WR5position.append(position)
                WR5team.append(team)
                WR5win.append(win)
                WR5points.append(points)
            if team_position == "TE6":
                TE6name.append(name)
                TE6position.append(position)
                TE6team.append(team)
                TE6win.append(win)
                TE6points.append(points)
            if team_position == "W/R7":
                W_R7name.append(name)
                W_R7position.append(position)
                W_R7team.append(team)
                W_R7win.append(win)
                W_R7points.append(points)
            if team_position == "K8":
                K8name.append(name)
                K8position.append(position)
                K8team.append(team)
                K8win.append(win)
                K8points.append(points)
            if team_position == "DEF9":
                DEF9name.append(name)
                DEF9position.append(position)
                DEF9team.append(team)
                DEF9win.append(win)
                DEF9points.append(points)
    df['QB1name'] = QB1name
    df['QB1position'] = QB1position
    df['QB1team'] = QB1team
    df['QB1win'] = QB1win
    df['QB1points'] = QB1points
    df['RB2name'] = RB2name
    df['RB2position'] = RB2position
    df['RB2team'] = RB2team
    df['RB2win'] = RB2win
    df['RB2points'] = RB2points
    df['RB3name'] = RB3name
    df['RB3position'] = RB3position
    df['RB3team'] = RB3team
    df['RB3win'] = RB3win
    df['RB3points'] = RB3points
    df['WR4name'] = WR4name
    df['WR4position'] = WR4position
    df['WR4team'] = WR4team
    df['WR4win'] = WR4win
    df['WR4points'] = WR4points
    df['WR5name'] = WR5name
    df['WR5position'] = WR5position
    df['WR5team'] = WR5team
    df['WR5win'] = WR5win
    df['WR5points'] = WR5points
    df['K8name'] = K8name
    df['K8position'] = K8position
    df['K8team'] = K8team
    df['K8win'] = K8win
    df['K8points'] = K8points
    df['W_R7name'] = W_R7name
    df['W_R7position'] = W_R7position
    df['W_R7team'] = W_R7team
    df['W_R7win'] = W_R7win
    df['W_R7points'] = W_R7points
    df['TE6name'] = TE6name
    df['TE6position'] = TE6position
    df['TE6team'] = TE6team
    df['TE6win'] = TE6win
    df['TE6points'] = TE6points
    df['DEF9name'] = DEF9name
    df['DEF9position'] = DEF9position
    df['DEF9team'] = DEF9team
    df['DEF9win'] = DEF9win
    df['DEF9points'] = DEF9points
    df['Points'] = team_score
    df['Opponent'] = opponent_score
    df['Margin'] = margin
    df['Win'] = wins
    
    print("Wins: " + str(df['Win'].sum()))
    print("Avg. Margin of Victory: " + str(df['Margin'].mean()))
    print("Number of Wins Without a 15+ point QB: " + str(len(df[(df['Win'] == True) & (df['QB1points'] < 15.01)])))
    
    
    total_points = df["QB1points"].sum() + df["RB2points"].sum() + df["RB3points"].sum()
    total_points = total_points + df["WR4points"].sum() + df["WR5points"].sum() + df["K8points"].sum() + df["W_R7points"].sum()
    total_points = total_points + df["TE6points"].sum() + df["DEF9points"].sum() 
   
    print(teams[a])
    print("Number of Starting QBs: " + str(len(df[["QB1name","QB1position","QB1team","QB1win","QB1points"]].groupby("QB1name"))))
    print("QB Average: " + str(df["QB1points"].mean()))
    print("QB Median: " + str(df["QB1points"].median()))
    print("QB Weeks less than 12: " + str(df[df["QB1points"] < 12]["QB1name"].count()))
    print("QB Weeks more than 20: " + str(df[df["QB1points"] > 20]["QB1name"].count()))
    print("Percentage of Points from QB: " + str(df["QB1points"].sum()/total_points * 100))

    qb_starts = df[["QB1name","QB1points"]].groupby("QB1name").count().sort_values("QB1points", ascending=False)
    qb_points = df[["QB1name","QB1points"]].groupby("QB1name").mean().sort_values("QB1points", ascending=False)
    qb = pd.merge(qb_starts, qb_points, on="QB1name")
    print(qb)
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\Anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# ~\Anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~\Anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ...

# %%
## url setup
for a in range(1,13):
    df = pd.DataFrame()
    QB1name = []
    QB1position = []
    QB1team = []
    QB1win = []
    QB1points = []
    RB2name = []
    RB2position = []
    RB2team = []
    RB2win = []
    RB2points = []
    RB3name = []
    RB3position = []
    RB3team = []
    RB3win = []
    RB3points = []
    WR4name = []
    WR4position = []
    WR4team = []
    WR4win = []
    WR4points = []
    WR5name = []
    WR5position = []
    WR5team = []
    WR5win = []
    WR5points = []
    TE6name = []
    TE6position = []
    TE6team = []
    TE6win = []
    TE6points = []
    W_R7name = []
    W_R7position = []
    W_R7team = []
    W_R7win = []
    W_R7points = []
    K8name = []
    K8position = []
    K8team = []
    K8win = []
    K8points = []
    DEF9name = []
    DEF9position = []
    DEF9team = []
    DEF9win = []
    DEF9points = []

    site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
    site2 = '&week='
    teamNumber = a

    for j in range(0,13):
        weekNumber = j+1
        site = site1 + str(teamNumber) + site2 + str(weekNumber)
        html = urllib.urlopen(site)
        soup = BeautifulSoup(html.read())

        player_stats = soup.find("div",{"class": "tableWrap"})
        tr_tags = player_stats.find_all("tr")
        for i in range(2, len(tr_tags)):
            team_position = tr_tags[i].find("td",{"class": "teamPosition"}).get_text() + str(i-1)
            info = tr_tags[i].find("td",{"class": "playerNameAndInfo"})
            if info.find("a", {"class": "playerCard"}) is not None:
                name = info.find("a", {"class": "playerCard"}).get_text()
            else:
                name = "N/A"
            if info.find("em") is not None:
                position = info.find("em").get_text().split()[0]
                if len(info.find("em").get_text().split()) > 1:
                    team = info.find("em").get_text().split()[2]
                else:
                    team = "N/A"
            else:
                position = "N/A"
                team = "N/A"
            if tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text() is not None:
                if len(tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()) > 0:
                    win = tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()[0]
                else:
                    win = "N/A"
            else:
                win = "N/A"
            if tr_tags[i].find("span",{"class": "playerTotal"}) is not None:
                points = float(tr_tags[i].find("span",{"class": "playerTotal"}).get_text())
            else:
                points = 0

            if team_position == "QB1":
                QB1name.append(name)
                QB1position.append(position)
                QB1team.append(team)
                QB1win.append(win)
                QB1points.append(points)
            if team_position == "RB2":
                RB2name.append(name)
                RB2position.append(position)
                RB2team.append(team)
                RB2win.append(win)
                RB2points.append(points)
            if team_position == "RB3":
                RB3name.append(name)
                RB3position.append(position)
                RB3team.append(team)
                RB3win.append(win)
                RB3points.append(points)
            if team_position == "WR4":
                WR4name.append(name)
                WR4position.append(position)
                WR4team.append(team)
                WR4win.append(win)
                WR4points.append(points)
            if team_position == "WR5":
                WR5name.append(name)
                WR5position.append(position)
                WR5team.append(team)
                WR5win.append(win)
                WR5points.append(points)
            if team_position == "TE6":
                TE6name.append(name)
                TE6position.append(position)
                TE6team.append(team)
                TE6win.append(win)
                TE6points.append(points)
            if team_position == "W/R7":
                W_R7name.append(name)
                W_R7position.append(position)
                W_R7team.append(team)
                W_R7win.append(win)
                W_R7points.append(points)
            if team_position == "K8":
                K8name.append(name)
                K8position.append(position)
                K8team.append(team)
                K8win.append(win)
                K8points.append(points)
            if team_position == "DEF9":
                DEF9name.append(name)
                DEF9position.append(position)
                DEF9team.append(team)
                DEF9win.append(win)
                DEF9points.append(points)
    df['QB1name'] = QB1name
    df['QB1position'] = QB1position
    df['QB1team'] = QB1team
    df['QB1win'] = QB1win
    df['QB1points'] = QB1points
    df['RB2name'] = RB2name
    df['RB2position'] = RB2position
    df['RB2team'] = RB2team
    df['RB2win'] = RB2win
    df['RB2points'] = RB2points
    df['RB3name'] = RB3name
    df['RB3position'] = RB3position
    df['RB3team'] = RB3team
    df['RB3win'] = RB3win
    df['RB3points'] = RB3points
    df['WR4name'] = WR4name
    df['WR4position'] = WR4position
    df['WR4team'] = WR4team
    df['WR4win'] = WR4win
    df['WR4points'] = WR4points
    df['WR5name'] = WR5name
    df['WR5position'] = WR5position
    df['WR5team'] = WR5team
    df['WR5win'] = WR5win
    df['WR5points'] = WR5points
    df['K8name'] = K8name
    df['K8position'] = K8position
    df['K8team'] = K8team
    df['K8win'] = K8win
    df['K8points'] = K8points
    df['W_R7name'] = W_R7name
    df['W_R7position'] = W_R7position
    df['W_R7team'] = W_R7team
    df['W_R7win'] = W_R7win
    df['W_R7points'] = W_R7points
    df['TE6name'] = TE6name
    df['TE6position'] = TE6position
    df['TE6team'] = TE6team
    df['TE6win'] = TE6win
    df['TE6points'] = TE6points
    df['DEF9name'] = DEF9name
    df['DEF9position'] = DEF9position
    df['DEF9team'] = DEF9team
    df['DEF9win'] = DEF9win
    df['DEF9points'] = DEF9points
    total_points = df["QB1points"].sum() + df["RB2points"].sum() + df["RB3points"].sum()
    total_points = total_points + df["WR4points"].sum() + df["WR5points"].sum() + df["K8points"].sum() + df["W_R7points"].sum()
    total_points = total_points + df["TE6points"].sum() + df["DEF9points"].sum() 
   
    print(teams[a])
    rb = pd.DataFrame()
    rb["name"] = RB2name + RB3name + df[df["W_R7position"]== "RB"]["W_R7name"].values.tolist()
    rb["position"] = RB2position + RB3position + df[df["W_R7position"]== "RB"]["W_R7position"].values.tolist()
    rb["team"] = RB2team + RB3team + df[df["W_R7position"]== "RB"]["W_R7team"].values.tolist()
    rb["win"] = RB2win + RB3win + df[df["W_R7position"]== "RB"]["W_R7win"].values.tolist()
    rb["points"] = RB2points + RB3points + df[df["W_R7position"]== "RB"]["W_R7points"].values.tolist()
    
    print("Number of Starting RBs: " + str(len(rb.groupby("name"))))
    print("RB Average: " + str(rb["points"].mean()))
    print("RB Median: " + str(rb["points"].median()))
    print("RB Weeks less than 9: " + str(rb[rb["points"] < 9]["name"].count()))
    print("RB Weeks more than 10: " + str(rb[rb["points"] > 10]["name"].count()))
    print("RB Weeks more than 15: " + str(rb[rb["points"] > 15]["name"].count()))
    print("Percentage of Points from RB: " + str(rb["points"].sum()/total_points * 100))
    

    rb_starts = rb[["name","points"]].groupby("name").count().sort_values("points", ascending=False)
    rb_points = rb[["name","points"]].groupby("name").mean().sort_values("points", ascending=False)

    print("RBs Started/Week: " + str(rb_starts["points"].sum()/13))
    print("RB Points/Week: " + str(rb["points"].mean() * rb_starts["points"].sum()/13))
    rb1 = pd.merge(rb_starts, rb_points, on="name")
    print(rb1)
    print("\n")
# Out:
# Number Juan
# Number of Starting RBs: 6
# RB Average: 7.6538461538461515
# RB Median: 6.8
# RB Weeks less than 9: 15
# RB Weeks more than 10: 6
# RB Weeks more than 15: 3
# Percentage of Points from RB: 14.294950075425614
# RBs Started/Week: 2.0
# RB Points/Week: 15.307692307692303
#                points_x   points_y
# name
# D. Singletary        11   7.909091
# A. Peterson           9   8.966667
# R. Burkhead           2   2.900000
# S. Barkley            2   6.200000
# D. Dallas             1   0.000000
# J. Dobbins            1  13.100000
#
#
# Belichick Yourself
# Number of Starting RBs: 6
# RB Average: 13.085714285714287
# RB Median: 11.65
# RB Weeks less than 9: 11
# RB Weeks more than 10: 17
# RB Weeks more than 15: 8
# Percentage of Points from RB: 26.291618828932258
# RBs Started/Week: 2.1538461538461537
# RB Points/Week: 28.184615384615388
#              points_x   points_y
# name
# D. Henry           12  18.283333
# J. Williams         7  11.728571
# ...

# %%
## url setup
wr_final = pd.DataFrame()
starters_l = []
average_l = []
med_l = []
less7_l = []
more12_l = []
percent_l = []
starts_week_l = []
points_week_l = []


for a in range(1,13):
    df = pd.DataFrame()
    QB1name = []
    QB1position = []
    QB1team = []
    QB1win = []
    QB1points = []
    RB2name = []
    RB2position = []
    RB2team = []
    RB2win = []
    RB2points = []
    RB3name = []
    RB3position = []
    RB3team = []
    RB3win = []
    RB3points = []
    WR4name = []
    WR4position = []
    WR4team = []
    WR4win = []
    WR4points = []
    WR5name = []
    WR5position = []
    WR5team = []
    WR5win = []
    WR5points = []
    TE6name = []
    TE6position = []
    TE6team = []
    TE6win = []
    TE6points = []
    W_R7name = []
    W_R7position = []
    W_R7team = []
    W_R7win = []
    W_R7points = []
    K8name = []
    K8position = []
    K8team = []
    K8win = []
    K8points = []
    DEF9name = []
    DEF9position = []
    DEF9team = []
    DEF9win = []
    DEF9points = []

    site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
    site2 = '&week='
    teamNumber = a

    for j in range(0,13):
        weekNumber = j+1
        site = site1 + str(teamNumber) + site2 + str(weekNumber)
        html = urllib.urlopen(site)
        soup = BeautifulSoup(html.read())

        player_stats = soup.find("div",{"class": "tableWrap"})
        tr_tags = player_stats.find_all("tr")
        for i in range(2, len(tr_tags)):
            team_position = tr_tags[i].find("td",{"class": "teamPosition"}).get_text() + str(i-1)
            info = tr_tags[i].find("td",{"class": "playerNameAndInfo"})
            if info.find("a", {"class": "playerCard"}) is not None:
                name = info.find("a", {"class": "playerCard"}).get_text()
            else:
                name = "N/A"
            if info.find("em") is not None:
                position = info.find("em").get_text().split()[0]
                if len(info.find("em").get_text().split()) > 1:
                    team = info.find("em").get_text().split()[2]
                else:
                    team = "N/A"
            else:
                position = "N/A"
                team = "N/A"
            if tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text() is not None:
                if len(tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()) > 0:
                    win = tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()[0]
                else:
                    win = "N/A"
            else:
                win = "N/A"
            if tr_tags[i].find("span",{"class": "playerTotal"}) is not None:
                points = float(tr_tags[i].find("span",{"class": "playerTotal"}).get_text())
            else:
                points = 0

            if team_position == "QB1":
                QB1name.append(name)
                QB1position.append(position)
                QB1team.append(team)
                QB1win.append(win)
                QB1points.append(points)
            if team_position == "RB2":
                RB2name.append(name)
                RB2position.append(position)
                RB2team.append(team)
                RB2win.append(win)
                RB2points.append(points)
            if team_position == "RB3":
                RB3name.append(name)
                RB3position.append(position)
                RB3team.append(team)
                RB3win.append(win)
                RB3points.append(points)
            if team_position == "WR4":
                WR4name.append(name)
                WR4position.append(position)
                WR4team.append(team)
                WR4win.append(win)
                WR4points.append(points)
            if team_position == "WR5":
                WR5name.append(name)
                WR5position.append(position)
                WR5team.append(team)
                WR5win.append(win)
                WR5points.append(points)
            if team_position == "TE6":
                TE6name.append(name)
                TE6position.append(position)
                TE6team.append(team)
                TE6win.append(win)
                TE6points.append(points)
            if team_position == "W/R7":
                W_R7name.append(name)
                W_R7position.append(position)
                W_R7team.append(team)
                W_R7win.append(win)
                W_R7points.append(points)
            if team_position == "K8":
                K8name.append(name)
                K8position.append(position)
                K8team.append(team)
                K8win.append(win)
                K8points.append(points)
            if team_position == "DEF9":
                DEF9name.append(name)
                DEF9position.append(position)
                DEF9team.append(team)
                DEF9win.append(win)
                DEF9points.append(points)
    df['QB1name'] = QB1name
    df['QB1position'] = QB1position
    df['QB1team'] = QB1team
    df['QB1win'] = QB1win
    df['QB1points'] = QB1points
    df['RB2name'] = RB2name
    df['RB2position'] = RB2position
    df['RB2team'] = RB2team
    df['RB2win'] = RB2win
    df['RB2points'] = RB2points
    df['RB3name'] = RB3name
    df['RB3position'] = RB3position
    df['RB3team'] = RB3team
    df['RB3win'] = RB3win
    df['RB3points'] = RB3points
    df['WR4name'] = WR4name
    df['WR4position'] = WR4position
    df['WR4team'] = WR4team
    df['WR4win'] = WR4win
    df['WR4points'] = WR4points
    df['WR5name'] = WR5name
    df['WR5position'] = WR5position
    df['WR5team'] = WR5team
    df['WR5win'] = WR5win
    df['WR5points'] = WR5points
    df['K8name'] = K8name
    df['K8position'] = K8position
    df['K8team'] = K8team
    df['K8win'] = K8win
    df['K8points'] = K8points
    df['W_R7name'] = W_R7name
    df['W_R7position'] = W_R7position
    df['W_R7team'] = W_R7team
    df['W_R7win'] = W_R7win
    df['W_R7points'] = W_R7points
    df['TE6name'] = TE6name
    df['TE6position'] = TE6position
    df['TE6team'] = TE6team
    df['TE6win'] = TE6win
    df['TE6points'] = TE6points
    df['DEF9name'] = DEF9name
    df['DEF9position'] = DEF9position
    df['DEF9team'] = DEF9team
    df['DEF9win'] = DEF9win
    df['DEF9points'] = DEF9points
    total_points = df["QB1points"].sum() + df["RB2points"].sum() + df["RB3points"].sum()
    total_points = total_points + df["WR4points"].sum() + df["WR5points"].sum() + df["K8points"].sum() + df["W_R7points"].sum()
    total_points = total_points + df["TE6points"].sum() + df["DEF9points"].sum() 
   
    print(teams[a])
    wr = pd.DataFrame()
    wr["name"] = WR4name + WR5name + df[df["W_R7position"]== "WR"]["W_R7name"].values.tolist()
    wr["position"] = WR4position + WR5position + df[df["W_R7position"]== "WR"]["W_R7position"].values.tolist()
    wr["team"] = WR4team + WR5team + df[df["W_R7position"]== "WR"]["W_R7team"].values.tolist()
    wr["win"] = WR5win + WR4win + df[df["W_R7position"]== "WR"]["W_R7win"].values.tolist()
    wr["points"] = WR4points + WR5points + df[df["W_R7position"]== "WR"]["W_R7points"].values.tolist()
    
    starters = len(wr.groupby("name"))
    average = wr["points"].mean()
    med = wr["points"].median()
    less7 = wr[wr["points"] < 7]["name"].count()
    more12 = wr[wr["points"] > 12]["name"].count()
    percent = wr["points"].sum()/total_points * 100
    
    starters_l.append(starters)
    average_l.append(average)
    med_l.append(med)
    less7_l.append(less7)
    more12_l.append(more12)
    percent_l.append(percent)
   
    
    print("Number of Starting WRs: " + str(starters))
    print("WR Average: " + str(average))
    print("WR Median: " + str(med))
    print("WR Weeks less than 7: " + str(less7))
    print("WR Weeks more than 12: " + str(more12))
    print("Percentage of Points from WR: " + str(percent))

    wr_starts = wr[["name","points"]].groupby("name").count().sort_values("points", ascending=False)
    wr_points = wr[["name","points"]].groupby("name").mean().sort_values("points", ascending=False)
    
    starts_week = wr_starts["points"].sum()/13
    points_week = wr["points"].mean() * wr_starts["points"].sum()/13
    
    starts_week_l.append(starts_week)
    points_week_l.append(points_week)
    
    print("WRs Started/Week: " + str(starts_week))
    print("WR Points/Week: " + str(points_week))
    
    wr1 = pd.merge(wr_starts, wr_points, on="name")
    print(wr1)
    print("\n")

wr_final["Number of Starting WRs"] = starters_l
wr_final["WR Average"] = average_l
wr_final["WR Median: "] = med_l
wr_final["WR Weeks less than 7: "] = less7_l
wr_final["WR Weeks more than 12: "] = more12_l
wr_final["Percentage of Points from WR: "] = percent_l
wr_final["WRs Started/Week: "] = starts_week_l
wr_final["WR Points/Week: "] = points_week_l

# %%
wr_final = wr_final.rename(index={
    0 : "Number Juan",
    1 : "Belichick Yourself",
    2 : "Scott",
    3 : "Hernandez Hit Men",
    4 : "Ayush",
    5 : "Krishanu",
    6 : "Matthew",
    7 : "Ankith",
    8 : "Bok Choy Babes",
    9 : "Davis",
    10 : "Ishaan",
    11 : "Nandha"
})
wr_final.to_csv('wr.csv')

# %%
## url setup
for a in range(1,13):
    df = pd.DataFrame()
    QB1name = []
    QB1position = []
    QB1team = []
    QB1win = []
    QB1points = []
    RB2name = []
    RB2position = []
    RB2team = []
    RB2win = []
    RB2points = []
    RB3name = []
    RB3position = []
    RB3team = []
    RB3win = []
    RB3points = []
    WR4name = []
    WR4position = []
    WR4team = []
    WR4win = []
    WR4points = []
    WR5name = []
    WR5position = []
    WR5team = []
    WR5win = []
    WR5points = []
    TE6name = []
    TE6position = []
    TE6team = []
    TE6win = []
    TE6points = []
    W_R7name = []
    W_R7position = []
    W_R7team = []
    W_R7win = []
    W_R7points = []
    K8name = []
    K8position = []
    K8team = []
    K8win = []
    K8points = []
    DEF9name = []
    DEF9position = []
    DEF9team = []
    DEF9win = []
    DEF9points = []

    site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
    site2 = '&week='
    teamNumber = a

    for j in range(0,13):
        weekNumber = j+1
        site = site1 + str(teamNumber) + site2 + str(weekNumber)
        html = urllib.urlopen(site)
        soup = BeautifulSoup(html.read())

        player_stats = soup.find("div",{"class": "tableWrap"})
        tr_tags = player_stats.find_all("tr")
        for i in range(2, len(tr_tags)):
            team_position = tr_tags[i].find("td",{"class": "teamPosition"}).get_text() + str(i-1)
            info = tr_tags[i].find("td",{"class": "playerNameAndInfo"})
            if info.find("a", {"class": "playerCard"}) is not None:
                name = info.find("a", {"class": "playerCard"}).get_text()
            else:
                name = "N/A"
            if info.find("em") is not None:
                position = info.find("em").get_text().split()[0]
                if len(info.find("em").get_text().split()) > 1:
                    team = info.find("em").get_text().split()[2]
                else:
                    team = "N/A"
            else:
                position = "N/A"
                team = "N/A"
            if tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text() is not None:
                if len(tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()) > 0:
                    win = tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()[0]
                else:
                    win = "N/A"
            else:
                win = "N/A"
            if tr_tags[i].find("span",{"class": "playerTotal"}) is not None:
                points = float(tr_tags[i].find("span",{"class": "playerTotal"}).get_text())
            else:
                points = 0

            if team_position == "QB1":
                QB1name.append(name)
                QB1position.append(position)
                QB1team.append(team)
                QB1win.append(win)
                QB1points.append(points)
            if team_position == "RB2":
                RB2name.append(name)
                RB2position.append(position)
                RB2team.append(team)
                RB2win.append(win)
                RB2points.append(points)
            if team_position == "RB3":
                RB3name.append(name)
                RB3position.append(position)
                RB3team.append(team)
                RB3win.append(win)
                RB3points.append(points)
            if team_position == "WR4":
                WR4name.append(name)
                WR4position.append(position)
                WR4team.append(team)
                WR4win.append(win)
                WR4points.append(points)
            if team_position == "WR5":
                WR5name.append(name)
                WR5position.append(position)
                WR5team.append(team)
                WR5win.append(win)
                WR5points.append(points)
            if team_position == "TE6":
                TE6name.append(name)
                TE6position.append(position)
                TE6team.append(team)
                TE6win.append(win)
                TE6points.append(points)
            if team_position == "W/R7":
                W_R7name.append(name)
                W_R7position.append(position)
                W_R7team.append(team)
                W_R7win.append(win)
                W_R7points.append(points)
            if team_position == "K8":
                K8name.append(name)
                K8position.append(position)
                K8team.append(team)
                K8win.append(win)
                K8points.append(points)
            if team_position == "DEF9":
                DEF9name.append(name)
                DEF9position.append(position)
                DEF9team.append(team)
                DEF9win.append(win)
                DEF9points.append(points)
    df['QB1name'] = QB1name
    df['QB1position'] = QB1position
    df['QB1team'] = QB1team
    df['QB1win'] = QB1win
    df['QB1points'] = QB1points
    df['RB2name'] = RB2name
    df['RB2position'] = RB2position
    df['RB2team'] = RB2team
    df['RB2win'] = RB2win
    df['RB2points'] = RB2points
    df['RB3name'] = RB3name
    df['RB3position'] = RB3position
    df['RB3team'] = RB3team
    df['RB3win'] = RB3win
    df['RB3points'] = RB3points
    df['WR4name'] = WR4name
    df['WR4position'] = WR4position
    df['WR4team'] = WR4team
    df['WR4win'] = WR4win
    df['WR4points'] = WR4points
    df['WR5name'] = WR5name
    df['WR5position'] = WR5position
    df['WR5team'] = WR5team
    df['WR5win'] = WR5win
    df['WR5points'] = WR5points
    df['K8name'] = K8name
    df['K8position'] = K8position
    df['K8team'] = K8team
    df['K8win'] = K8win
    df['K8points'] = K8points
    df['W_R7name'] = W_R7name
    df['W_R7position'] = W_R7position
    df['W_R7team'] = W_R7team
    df['W_R7win'] = W_R7win
    df['W_R7points'] = W_R7points
    df['TE6name'] = TE6name
    df['TE6position'] = TE6position
    df['TE6team'] = TE6team
    df['TE6win'] = TE6win
    df['TE6points'] = TE6points
    df['DEF9name'] = DEF9name
    df['DEF9position'] = DEF9position
    df['DEF9team'] = DEF9team
    df['DEF9win'] = DEF9win
    df['DEF9points'] = DEF9points
    total_points = df["QB1points"].sum() + df["RB2points"].sum() + df["RB3points"].sum()
    total_points = total_points + df["WR4points"].sum() + df["WR5points"].sum() + df["K8points"].sum() + df["W_R7points"].sum()
    total_points = total_points + df["TE6points"].sum() + df["DEF9points"].sum() 
   
    print(teams[a])
    print("Number of Starting TEs: " + str(len(df[["TE6name","TE6position","QB1team","TE6win","TE6points"]].groupby("TE6name"))))
    print("TE Average: " + str(df["TE6points"].mean()))
    print("TE Median: " + str(df["TE6points"].median()))
    print("TE Weeks less than 5: " + str(df[df["TE6points"] < 5]["TE6name"].count()))
    print("TE Weeks more than 8: " + str(df[df["TE6points"] > 8]["TE6name"].count()))
    print("Percentage of Points from TE: " + str(df["TE6points"].sum()/total_points * 100))

    te_starts = df[["TE6name","TE6points"]].groupby("TE6name").count().sort_values("TE6points", ascending=False)
    te_points = df[["TE6name","TE6points"]].groupby("TE6name").mean().sort_values("TE6points", ascending=False)
    te = pd.merge(te_starts, te_points, on="TE6name")
    print(te)
    print("\n")

# %%
## url setup
for a in range(1,13):
    df = pd.DataFrame()
    QB1name = []
    QB1position = []
    QB1team = []
    QB1win = []
    QB1points = []
    RB2name = []
    RB2position = []
    RB2team = []
    RB2win = []
    RB2points = []
    RB3name = []
    RB3position = []
    RB3team = []
    RB3win = []
    RB3points = []
    WR4name = []
    WR4position = []
    WR4team = []
    WR4win = []
    WR4points = []
    WR5name = []
    WR5position = []
    WR5team = []
    WR5win = []
    WR5points = []
    TE6name = []
    TE6position = []
    TE6team = []
    TE6win = []
    TE6points = []
    W_R7name = []
    W_R7position = []
    W_R7team = []
    W_R7win = []
    W_R7points = []
    K8name = []
    K8position = []
    K8team = []
    K8win = []
    K8points = []
    DEF9name = []
    DEF9position = []
    DEF9team = []
    DEF9win = []
    DEF9points = []

    site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
    site2 = '&week='
    teamNumber = a

    for j in range(0,13):
        weekNumber = j+1
        site = site1 + str(teamNumber) + site2 + str(weekNumber)
        html = urllib.urlopen(site)
        soup = BeautifulSoup(html.read())

        player_stats = soup.find("div",{"class": "tableWrap"})
        tr_tags = player_stats.find_all("tr")
        for i in range(2, len(tr_tags)):
            team_position = tr_tags[i].find("td",{"class": "teamPosition"}).get_text() + str(i-1)
            info = tr_tags[i].find("td",{"class": "playerNameAndInfo"})
            if info.find("a", {"class": "playerCard"}) is not None:
                name = info.find("a", {"class": "playerCard"}).get_text()
            else:
                name = "N/A"
            if info.find("em") is not None:
                position = info.find("em").get_text().split()[0]
                if len(info.find("em").get_text().split()) > 1:
                    team = info.find("em").get_text().split()[2]
                else:
                    team = "N/A"
            else:
                position = "N/A"
                team = "N/A"
            if tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text() is not None:
                if len(tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()) > 0:
                    win = tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()[0]
                else:
                    win = "N/A"
            else:
                win = "N/A"
            if tr_tags[i].find("span",{"class": "playerTotal"}) is not None:
                points = float(tr_tags[i].find("span",{"class": "playerTotal"}).get_text())
            else:
                points = 0

            if team_position == "QB1":
                QB1name.append(name)
                QB1position.append(position)
                QB1team.append(team)
                QB1win.append(win)
                QB1points.append(points)
            if team_position == "RB2":
                RB2name.append(name)
                RB2position.append(position)
                RB2team.append(team)
                RB2win.append(win)
                RB2points.append(points)
            if team_position == "RB3":
                RB3name.append(name)
                RB3position.append(position)
                RB3team.append(team)
                RB3win.append(win)
                RB3points.append(points)
            if team_position == "WR4":
                WR4name.append(name)
                WR4position.append(position)
                WR4team.append(team)
                WR4win.append(win)
                WR4points.append(points)
            if team_position == "WR5":
                WR5name.append(name)
                WR5position.append(position)
                WR5team.append(team)
                WR5win.append(win)
                WR5points.append(points)
            if team_position == "TE6":
                TE6name.append(name)
                TE6position.append(position)
                TE6team.append(team)
                TE6win.append(win)
                TE6points.append(points)
            if team_position == "W/R7":
                W_R7name.append(name)
                W_R7position.append(position)
                W_R7team.append(team)
                W_R7win.append(win)
                W_R7points.append(points)
            if team_position == "K8":
                K8name.append(name)
                K8position.append(position)
                K8team.append(team)
                K8win.append(win)
                K8points.append(points)
            if team_position == "DEF9":
                DEF9name.append(name)
                DEF9position.append(position)
                DEF9team.append(team)
                DEF9win.append(win)
                DEF9points.append(points)
    df['QB1name'] = QB1name
    df['QB1position'] = QB1position
    df['QB1team'] = QB1team
    df['QB1win'] = QB1win
    df['QB1points'] = QB1points
    df['RB2name'] = RB2name
    df['RB2position'] = RB2position
    df['RB2team'] = RB2team
    df['RB2win'] = RB2win
    df['RB2points'] = RB2points
    df['RB3name'] = RB3name
    df['RB3position'] = RB3position
    df['RB3team'] = RB3team
    df['RB3win'] = RB3win
    df['RB3points'] = RB3points
    df['WR4name'] = WR4name
    df['WR4position'] = WR4position
    df['WR4team'] = WR4team
    df['WR4win'] = WR4win
    df['WR4points'] = WR4points
    df['WR5name'] = WR5name
    df['WR5position'] = WR5position
    df['WR5team'] = WR5team
    df['WR5win'] = WR5win
    df['WR5points'] = WR5points
    df['K8name'] = K8name
    df['K8position'] = K8position
    df['K8team'] = K8team
    df['K8win'] = K8win
    df['K8points'] = K8points
    df['W_R7name'] = W_R7name
    df['W_R7position'] = W_R7position
    df['W_R7team'] = W_R7team
    df['W_R7win'] = W_R7win
    df['W_R7points'] = W_R7points
    df['TE6name'] = TE6name
    df['TE6position'] = TE6position
    df['TE6team'] = TE6team
    df['TE6win'] = TE6win
    df['TE6points'] = TE6points
    df['DEF9name'] = DEF9name
    df['DEF9position'] = DEF9position
    df['DEF9team'] = DEF9team
    df['DEF9win'] = DEF9win
    df['DEF9points'] = DEF9points
    total_points = df["QB1points"].sum() + df["RB2points"].sum() + df["RB3points"].sum()
    total_points = total_points + df["WR4points"].sum() + df["WR5points"].sum() + df["K8points"].sum() + df["W_R7points"].sum()
    total_points = total_points + df["TE6points"].sum() + df["DEF9points"].sum() 
   
    print(teams[a])
    print("Number of Starting DEFs: " + str(len(df[["DEF9name","DEF9position","DEF9team","DEF9win","DEF9points"]].groupby("DEF9name"))))
    print("DEF Average: " + str(df["DEF9points"].mean()))
    print("DEF Median: " + str(df["DEF9points"].median()))
    print("DEF Weeks less than 4: " + str(df[df["DEF9points"] < 4]["DEF9name"].count()))
    print("DEF Weeks more than 9: " + str(df[df["DEF9points"] > 9]["DEF9name"].count()))
    print("Percentage of Points from DEF: " + str(df["DEF9points"].sum()/total_points * 100))

    def_starts = df[["DEF9name","DEF9points"]].groupby("DEF9name").count().sort_values("DEF9points", ascending=False)
    def_points = df[["DEF9name","DEF9points"]].groupby("DEF9name").mean().sort_values("DEF9points", ascending=False)
    defense = pd.merge(def_starts, def_points, on="DEF9name")
    print(defense)
    print("\n")

# %%
## url setup
for a in range(1,13):
    df = pd.DataFrame()
    QB1name = []
    QB1position = []
    QB1team = []
    QB1win = []
    QB1points = []
    RB2name = []
    RB2position = []
    RB2team = []
    RB2win = []
    RB2points = []
    RB3name = []
    RB3position = []
    RB3team = []
    RB3win = []
    RB3points = []
    WR4name = []
    WR4position = []
    WR4team = []
    WR4win = []
    WR4points = []
    WR5name = []
    WR5position = []
    WR5team = []
    WR5win = []
    WR5points = []
    TE6name = []
    TE6position = []
    TE6team = []
    TE6win = []
    TE6points = []
    W_R7name = []
    W_R7position = []
    W_R7team = []
    W_R7win = []
    W_R7points = []
    K8name = []
    K8position = []
    K8team = []
    K8win = []
    K8points = []
    DEF9name = []
    DEF9position = []
    DEF9team = []
    DEF9win = []
    DEF9points = []

    site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
    site2 = '&week='
    teamNumber = a

    for j in range(0,13):
        weekNumber = j+1
        site = site1 + str(teamNumber) + site2 + str(weekNumber)
        html = urllib.urlopen(site)
        soup = BeautifulSoup(html.read())

        player_stats = soup.find("div",{"class": "tableWrap"})
        tr_tags = player_stats.find_all("tr")
        for i in range(2, len(tr_tags)):
            team_position = tr_tags[i].find("td",{"class": "teamPosition"}).get_text() + str(i-1)
            info = tr_tags[i].find("td",{"class": "playerNameAndInfo"})
            if info.find("a", {"class": "playerCard"}) is not None:
                name = info.find("a", {"class": "playerCard"}).get_text()
            else:
                name = "N/A"
            if info.find("em") is not None:
                position = info.find("em").get_text().split()[0]
                if len(info.find("em").get_text().split()) > 1:
                    team = info.find("em").get_text().split()[2]
                else:
                    team = "N/A"
            else:
                position = "N/A"
                team = "N/A"
            if tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text() is not None:
                if len(tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()) > 0:
                    win = tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()[0]
                else:
                    win = "N/A"
            else:
                win = "N/A"
            if tr_tags[i].find("span",{"class": "playerTotal"}) is not None:
                points = float(tr_tags[i].find("span",{"class": "playerTotal"}).get_text())
            else:
                points = 0

            if team_position == "QB1":
                QB1name.append(name)
                QB1position.append(position)
                QB1team.append(team)
                QB1win.append(win)
                QB1points.append(points)
            if team_position == "RB2":
                RB2name.append(name)
                RB2position.append(position)
                RB2team.append(team)
                RB2win.append(win)
                RB2points.append(points)
            if team_position == "RB3":
                RB3name.append(name)
                RB3position.append(position)
                RB3team.append(team)
                RB3win.append(win)
                RB3points.append(points)
            if team_position == "WR4":
                WR4name.append(name)
                WR4position.append(position)
                WR4team.append(team)
                WR4win.append(win)
                WR4points.append(points)
            if team_position == "WR5":
                WR5name.append(name)
                WR5position.append(position)
                WR5team.append(team)
                WR5win.append(win)
                WR5points.append(points)
            if team_position == "TE6":
                TE6name.append(name)
                TE6position.append(position)
                TE6team.append(team)
                TE6win.append(win)
                TE6points.append(points)
            if team_position == "W/R7":
                W_R7name.append(name)
                W_R7position.append(position)
                W_R7team.append(team)
                W_R7win.append(win)
                W_R7points.append(points)
            if team_position == "K8":
                K8name.append(name)
                K8position.append(position)
                K8team.append(team)
                K8win.append(win)
                K8points.append(points)
            if team_position == "DEF9":
                DEF9name.append(name)
                DEF9position.append(position)
                DEF9team.append(team)
                DEF9win.append(win)
                DEF9points.append(points)
    df['QB1name'] = QB1name
    df['QB1position'] = QB1position
    df['QB1team'] = QB1team
    df['QB1win'] = QB1win
    df['QB1points'] = QB1points
    df['RB2name'] = RB2name
    df['RB2position'] = RB2position
    df['RB2team'] = RB2team
    df['RB2win'] = RB2win
    df['RB2points'] = RB2points
    df['RB3name'] = RB3name
    df['RB3position'] = RB3position
    df['RB3team'] = RB3team
    df['RB3win'] = RB3win
    df['RB3points'] = RB3points
    df['WR4name'] = WR4name
    df['WR4position'] = WR4position
    df['WR4team'] = WR4team
    df['WR4win'] = WR4win
    df['WR4points'] = WR4points
    df['WR5name'] = WR5name
    df['WR5position'] = WR5position
    df['WR5team'] = WR5team
    df['WR5win'] = WR5win
    df['WR5points'] = WR5points
    df['K8name'] = K8name
    df['K8position'] = K8position
    df['K8team'] = K8team
    df['K8win'] = K8win
    df['K8points'] = K8points
    df['W_R7name'] = W_R7name
    df['W_R7position'] = W_R7position
    df['W_R7team'] = W_R7team
    df['W_R7win'] = W_R7win
    df['W_R7points'] = W_R7points
    df['TE6name'] = TE6name
    df['TE6position'] = TE6position
    df['TE6team'] = TE6team
    df['TE6win'] = TE6win
    df['TE6points'] = TE6points
    df['DEF9name'] = DEF9name
    df['DEF9position'] = DEF9position
    df['DEF9team'] = DEF9team
    df['DEF9win'] = DEF9win
    df['DEF9points'] = DEF9points
    total_points = df["QB1points"].sum() + df["RB2points"].sum() + df["RB3points"].sum()
    total_points = total_points + df["WR4points"].sum() + df["WR5points"].sum() + df["K8points"].sum() + df["W_R7points"].sum()
    total_points = total_points + df["TE6points"].sum() + df["DEF9points"].sum() 
   
    print(teams[a])
    print("Number of Starting Ks: " + str(len(df[["K8name","K8position","K8team","K8win","K8points"]].groupby("K8name"))))
    print("K Average: " + str(df["K8points"].mean()))
    print("K Median: " + str(df["K8points"].median()))
    print("K Weeks less than 5: " + str(df[df["K8points"] < 5]["K8name"].count()))
    print("K Weeks more than 9: " + str(df[df["K8points"] > 9]["K8name"].count()))
    print("Percentage of Points from K: " + str(df["K8points"].sum()/total_points * 100))

    k_starts = df[["K8name","K8points"]].groupby("K8name").count().sort_values("K8points", ascending=False)
    k_points = df[["K8name","K8points"]].groupby("K8name").mean().sort_values("K8points", ascending=False)
    k = pd.merge(k_starts, k_points, on="K8name")
    print(k)
    print("\n")

# %%
## generic setup
df = pd.DataFrame()
QB1name = []
QB1position = []
QB1team = []
QB1win = []
QB1points = []
RB2name = []
RB2position = []
RB2team = []
RB2win = []
RB2points = []
RB3name = []
RB3position = []
RB3team = []
RB3win = []
RB3points = []
WR4name = []
WR4position = []
WR4team = []
WR4win = []
WR4points = []
WR5name = []
WR5position = []
WR5team = []
WR5win = []
WR5points = []
TE6name = []
TE6position = []
TE6team = []
TE6win = []
TE6points = []
W_R7name = []
W_R7position = []
W_R7team = []
W_R7win = []
W_R7points = []
K8name = []
K8position = []
K8team = []
K8win = []
K8points = []
DEF9name = []
DEF9position = []
DEF9team = []
DEF9win = []
DEF9points = []

    site1 = 'https://fantasy.nfl.com/league/2461806/history/2020/teamgamecenter?teamId='
    site2 = '&week='
    teamNumber = a

for j in range(0,13):
    weekNumber = j+1
    site = site1 + str(teamNumber) + site2 + str(weekNumber)
    html = urllib.urlopen(site)
    soup = BeautifulSoup(html.read())

    player_stats = soup.find("div",{"class": "tableWrap"})
    tr_tags = player_stats.find_all("tr")
    for i in range(2, len(tr_tags)):
        team_position = tr_tags[i].find("td",{"class": "teamPosition"}).get_text() + str(i-1)
        info = tr_tags[i].find("td",{"class": "playerNameAndInfo"})
        if info.find("a", {"class": "playerCard"}) is not None:
            name = info.find("a", {"class": "playerCard"}).get_text()
        else:
            name = "N/A"
        if info.find("em") is not None:
            position = info.find("em").get_text().split()[0]
            if len(info.find("em").get_text().split()) > 1:
                team = info.find("em").get_text().split()[2]
            else:
                team = "N/A"
        else:
            position = "N/A"
            team = "N/A"
        if tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text() is not None:
            if len(tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()) > 0:
                win = tr_tags[i].find("td",{"class": "playerGameStatus"}).get_text().split()[0]
            else:
                win = "N/A"
        else:
            win = "N/A"
        if tr_tags[i].find("span",{"class": "playerTotal"}) is not None:
            points = float(tr_tags[i].find("span",{"class": "playerTotal"}).get_text())
        else:
            points = 0

        if team_position == "QB1":
            QB1name.append(name)
            QB1position.append(position)
            QB1team.append(team)
            QB1win.append(win)
            QB1points.append(points)
        if team_position == "RB2":
            RB2name.append(name)
            RB2position.append(position)
            RB2team.append(team)
            RB2win.append(win)
            RB2points.append(points)
        if team_position == "RB3":
            RB3name.append(name)
            RB3position.append(position)
            RB3team.append(team)
            RB3win.append(win)
            RB3points.append(points)
        if team_position == "WR4":
            WR4name.append(name)
            WR4position.append(position)
            WR4team.append(team)
            WR4win.append(win)
            WR4points.append(points)
        if team_position == "WR5":
            WR5name.append(name)
            WR5position.append(position)
            WR5team.append(team)
            WR5win.append(win)
            WR5points.append(points)
        if team_position == "TE6":
            TE6name.append(name)
            TE6position.append(position)
            TE6team.append(team)
            TE6win.append(win)
            TE6points.append(points)
        if team_position == "W/R7":
            W_R7name.append(name)
            W_R7position.append(position)
            W_R7team.append(team)
            W_R7win.append(win)
            W_R7points.append(points)
        if team_position == "K8":
            K8name.append(name)
            K8position.append(position)
            K8team.append(team)
            K8win.append(win)
            K8points.append(points)
        if team_position == "DEF9":
            DEF9name.append(name)
            DEF9position.append(position)
            DEF9team.append(team)
            DEF9win.append(win)
            DEF9points.append(points)

# %%
### SCRAP BELOW

# %%
df['QB1name'] = QB1name
df['QB1position'] = QB1position
df['QB1team'] = QB1team
df['QB1win'] = QB1win
df['QB1points'] = QB1points
df['RB2name'] = RB2name
df['RB2position'] = RB2position
df['RB2team'] = RB2team
df['RB2win'] = RB2win
df['RB2points'] = RB2points
df['RB3name'] = RB3name
df['RB3position'] = RB3position
df['RB3team'] = RB3team
df['RB3win'] = RB3win
df['RB3points'] = RB3points
df['WR4name'] = WR4name
df['WR4position'] = WR4position
df['WR4team'] = WR4team
df['WR4win'] = WR4win
df['WR4points'] = WR4points
df['WR5name'] = WR5name
df['WR5position'] = WR5position
df['WR5team'] = WR5team
df['WR5win'] = WR5win
df['WR5points'] = WR5points
df['K8name'] = K8name
df['K8position'] = K8position
df['K8team'] = K8team
df['K8win'] = K8win
df['K8points'] = K8points
df['W_R7name'] = W_R7name
df['W_R7position'] = W_R7position
df['W_R7team'] = W_R7team
df['W_R7win'] = W_R7win
df['W_R7points'] = W_R7points
df['TE6name'] = TE6name
df['TE6position'] = TE6position
df['TE6team'] = TE6team
df['TE6win'] = TE6win
df['TE6points'] = TE6points
df['DEF9name'] = DEF9name
df['DEF9position'] = DEF9position
df['DEF9team'] = DEF9team
df['DEF9win'] = DEF9win
df['DEF9points'] = DEF9points

# %%
total_points = df["QB1points"].sum() + df["RB2points"].sum() + df["RB3points"].sum()
total_points = total_points + df["WR4points"].sum() + df["WR5points"].sum() + df["K8points"].sum() + df["W_R7points"].sum()
total_points = total_points + df["TE6points"].sum() + df["DEF9points"].sum() 
total_points

# %%
rb = pd.DataFrame()
rb["name"] = RB2name + RB3name + df[df["W_R7position"]== "RB"]["W_R7name"].values.tolist()
rb["position"] = RB2position + RB3position + df[df["W_R7position"]== "RB"]["W_R7position"].values.tolist()
rb["team"] = RB2team + RB3team + df[df["W_R7position"]== "RB"]["W_R7team"].values.tolist()
rb["win"] = RB2win + RB3win + df[df["W_R7position"]== "RB"]["W_R7win"].values.tolist()
rb["points"] = RB2points + RB3points + df[df["W_R7position"]== "RB"]["W_R7points"].values.tolist()

# %%
print("Number of Starting RBs: " + str(len(rb.groupby("name"))))
print("RB Average: " + str(rb["points"].mean()))
print("RB Median: " + str(rb["points"].median()))
print("RB Weeks less than 9: " + str(rb[rb["points"] < 9]["name"].count()))
print("RB Weeks more than 15: " + str(rb[rb["points"] > 15]["name"].count()))
print("Percentage of Points from RB: " + str(rb["points"].sum()/total_points * 100))

rb_starts = rb[["name","points"]].groupby("name").count().sort_values("points", ascending=False)
rb_points = rb[["name","points"]].groupby("name").mean().sort_values("points", ascending=False)
rb1 = pd.merge(rb_starts, rb_points, on="name")
print(rb1)

# %%
print("Number of Starting QBs: " + str(len(df[["QB1name","QB1position","QB1team","QB1win","QB1points"]].groupby("QB1name"))))
print("QB Average: " + str(df["QB1points"].mean()))
print("QB Median: " + str(df["QB1points"].median()))
print("QB Weeks less than 12: " + str(df[df["QB1points"] < 12]["QB1name"].count()))
print("QB Weeks more than 20: " + str(df[df["QB1points"] > 20]["QB1name"].count()))
print("Percentage of Points from QB: " + str(df["QB1points"].sum()/total_points * 100))

qb_starts = df[["QB1name","QB1points"]].groupby("QB1name").count().sort_values("QB1points", ascending=False)
qb_points = df[["QB1name","QB1points"]].groupby("QB1name").mean().sort_values("QB1points", ascending=False)
qb = pd.merge(qb_starts, qb_points, on="QB1name")
print(qb)

# %% [markdown]
#  df2 = [df['QB1name'][j],
#         df['QB1position'][j],
#         df['QB1team'][j],
#         df['QB1win'][j],
#         df['QB1points'][j],
#         df['RB2name'][j],
#         df['RB2position'][j],
#         df['RB2team'][j],
#         df['RB2win'][j],
#         df['RB2points'][j],
#         df['RB3name'][j],
#         df['RB3position'][j],
#         df['RB3team'][j],
#         df['RB3win'][j],
#         df['RB3points'][j],
#         df['WR4name'][j],
#         df['WR4position'][j],
#         df['WR4team'][j],
#         df['WR4win'][j],
#         df['WR4points'][j],
#         df['WR5name'][j],
#         df['WR5position'][j],
#         df['WR5team'][j],
#         df['WR5win'][j],
#         df['WR5points'][j],
#         df['K8name'][j],
#         df['K8position'][j],
#         df['K8team'][j],
#         df['K8win'][j],
#         df['K8points'][j],
#         df['W/R7name'][j],
#         df['W/R7position'][j],
#         df['W/R7team'][j],
#         df['W/R7win'][j],
#         df['W/R7points'][j],
#         df['TE6name'][j],
#         df['TE6position'][j],
#         df['TE6team'][j],
#         df['TE6win'][j],
#         df['TE6points'][j],
#         df['DEF9name'][j],
#         df['DEF9position'][j],
#         df['DEF9team'][j],
#         df['DEF9win'][j],
#         df['DEF9points'][j]]
#     df.append(df2)
